# %%
import pandas as pd
import numpy as np


# %pip install matplotlib
import matplotlib.pyplot as plt

# Configurar los gráficos para que se muestren en el notebook
# %matplotlib inline
import os

df = pd.read_csv('/Users/tardes/Documents/CIENCIADEDATOS/PYTHONCIENCIA/data/marvel_movies.csv')
df
# Out:
# Requirement already satisfied: matplotlib in /Users/tardes/Documents/CIENCIADEDATOS/PYTHONCIENCIA/.venv/lib/python3.13/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tardes/Documents/CIENCIADEDATOS/PYTHONCIENCIA/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/tardes/Documents/CIENCIADEDATOS/PYTHONCIENCIA/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tardes/Documents/CIENCIADEDATOS/PYTHONCIENCIA/.venv/lib/python3.13/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/tardes/Documents/CIENCIADEDATOS/PYTHONCIENCIA/.venv/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Users/tardes/Documents/CIENCIADEDATOS/PYTHONCIENCIA/.venv/lib/python3.13/site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /Users/tardes/Documents/CIENCIADEDATOS/PYTHONCIENCIA/.venv/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/tardes/Documents/CIENCIADEDATOS/PYTHONCIENCIA/.venv/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/tardes/Documents/CIENCIADEDATOS/PYTHONCIENCIA/.venv/lib/python3.13/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tardes/Documents/CIENCIADEDATOS/PYTHONCIENCIA/.venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/tardes/Documents/CIENCIADEDATOS/PYTHONCIENCIA/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
#                              titulo  year  duracion  presupuesto  recaudacion  \
# 0                          Iron Man  2008       126          140          585
# 1                      The Avengers  2012       143          220         1518
# 2                     Black Panther  2018       134          200         1347
# 3            Avengers: Infinity War  2018       149          316         2052
# 4                 Avengers: Endgame  2019       181          356         2798
# 5            SpiderMan: No Way Home  2021       148          200         1921
# 6           Guardians of the Galaxy  2014       121          170          773
# 7                    Doctor Strange  2016       115          165          677
# 8                    Thor: Ragnarok  2017       130          180          854
# 9                    Captain Marvel  2019       123          152         1128
# 10             Ant-Man and the Wasp  2018       118          130          622
# 11  Guardianes de la Galaxia vol. 2  2017       136          200          863
# 12                         Eternals  2021       156          236          402
# 13           Thor: Love and Thunder  2022       119          250          760
#
#                                            personajes  valoracion
# 0               Iron Man, Pepper Potts, Obadiah Stane         7.9
# 1               Iron Man, Capitan America, Thor, Hulk         8.0
# 2          Black Panther, T'Challa, Killmonger, Shuri         7.3
# 3   Iron Man, Capitan America, Thor, Thanos, Spide...         7.5
# 4   Iron Man, Capitan America, Thor, Thanos, Spide...         8.4
# 5             Spiderman, Doctor Strange, Green Goblin         8.2
# 6              Star-Lord, Gamora, Drax, Rocket, Groot         8.0
# 7                        Stephen Strange, Wong, Mordo         7.5
# 8                              Thor, Loki, Hela, Hulk         7.9
# 9                     Carol Danvers, Nick Fury, Talos         6.8
# 10                Scott Lang, Hope van Dyne, Hank Pym         7.0
# 11  Star-Lord, Gamora, Drax, Rocket, Groot, Mantis...         6.7
# 12  Caballero negro, Ikaris, Ajak, Sprite, Thena, ...         5.4
# 13    Gorr, Thor, Zeus, Korg, King Valkyrie, Heimdall         5.3

# %%
data_cleaned = df.dropna()
data_cleaned
# Out:
#                              titulo  year  duracion  presupuesto  recaudacion  \
# 0                          Iron Man  2008       126          140          585
# 1                      The Avengers  2012       143          220         1518
# 2                     Black Panther  2018       134          200         1347
# 3            Avengers: Infinity War  2018       149          316         2052
# 4                 Avengers: Endgame  2019       181          356         2798
# 5            SpiderMan: No Way Home  2021       148          200         1921
# 6           Guardians of the Galaxy  2014       121          170          773
# 7                    Doctor Strange  2016       115          165          677
# 8                    Thor: Ragnarok  2017       130          180          854
# 9                    Captain Marvel  2019       123          152         1128
# 10             Ant-Man and the Wasp  2018       118          130          622
# 11  Guardianes de la Galaxia vol. 2  2017       136          200          863
# 12                         Eternals  2021       156          236          402
# 13           Thor: Love and Thunder  2022       119          250          760
#
#                                            personajes  valoracion
# 0               Iron Man, Pepper Potts, Obadiah Stane         7.9
# 1               Iron Man, Capitan America, Thor, Hulk         8.0
# 2          Black Panther, T'Challa, Killmonger, Shuri         7.3
# 3   Iron Man, Capitan America, Thor, Thanos, Spide...         7.5
# 4   Iron Man, Capitan America, Thor, Thanos, Spide...         8.4
# 5             Spiderman, Doctor Strange, Green Goblin         8.2
# 6              Star-Lord, Gamora, Drax, Rocket, Groot         8.0
# 7                        Stephen Strange, Wong, Mordo         7.5
# 8                              Thor, Loki, Hela, Hulk         7.9
# 9                     Carol Danvers, Nick Fury, Talos         6.8
# 10                Scott Lang, Hope van Dyne, Hank Pym         7.0
# 11  Star-Lord, Gamora, Drax, Rocket, Groot, Mantis...         6.7
# 12  Caballero negro, Ikaris, Ajak, Sprite, Thena, ...         5.4
# 13    Gorr, Thor, Zeus, Korg, King Valkyrie, Heimdall         5.3

# %%
data_cleaned['year'] = pd.to_datetime(data_cleaned['year'], format='%Y')
data_cleaned
# Out:
#                              titulo                          year  duracion  \
# 0                          Iron Man 1970-01-01 00:00:00.000002008       126
# 1                      The Avengers 1970-01-01 00:00:00.000002012       143
# 2                     Black Panther 1970-01-01 00:00:00.000002018       134
# 3            Avengers: Infinity War 1970-01-01 00:00:00.000002018       149
# 4                 Avengers: Endgame 1970-01-01 00:00:00.000002019       181
# 5            SpiderMan: No Way Home 1970-01-01 00:00:00.000002021       148
# 6           Guardians of the Galaxy 1970-01-01 00:00:00.000002014       121
# 7                    Doctor Strange 1970-01-01 00:00:00.000002016       115
# 8                    Thor: Ragnarok 1970-01-01 00:00:00.000002017       130
# 9                    Captain Marvel 1970-01-01 00:00:00.000002019       123
# 10             Ant-Man and the Wasp 1970-01-01 00:00:00.000002018       118
# 11  Guardianes de la Galaxia vol. 2 1970-01-01 00:00:00.000002017       136
# 12                         Eternals 1970-01-01 00:00:00.000002021       156
# 13           Thor: Love and Thunder 1970-01-01 00:00:00.000002022       119
#
#     presupuesto  recaudacion  \
# 0           140          585
# 1           220         1518
# 2           200         1347
# 3           316         2052
# 4           356         2798
# 5           200         1921
# 6           170          773
# 7           165          677
# 8           180          854
# 9           152         1128
# 10          130          622
# 11          200          863
# 12          236          402
# 13          250          760
#
#                                            personajes  valoracion
# 0               Iron Man, Pepper Potts, Obadiah Stane         7.9
# 1               Iron Man, Capitan America, Thor, Hulk         8.0
# 2          Black Panther, T'Challa, Killmonger, Shuri         7.3
# 3   Iron Man, Capitan America, Thor, Thanos, Spide...         7.5
# 4   Iron Man, Capitan America, Thor, Thanos, Spide...         8.4
# 5             Spiderman, Doctor Strange, Green Goblin         8.2
# 6              Star-Lord, Gamora, Drax, Rocket, Groot         8.0
# 7                        Stephen Strange, Wong, Mordo         7.5
# 8                              Thor, Loki, Hela, Hulk         7.9
# 9                     Carol Danvers, Nick Fury, Talos         6.8
# 10                Scott Lang, Hope van Dyne, Hank Pym         7.0
# 11  Star-Lord, Gamora, Drax, Rocket, Groot, Mantis...         6.7
# 12  Caballero negro, Ikaris, Ajak, Sprite, Thena, ...         5.4
# 13    Gorr, Thor, Zeus, Korg, King Valkyrie, Heimdall         5.3

# %%
# Procesar Datos

# Eliminar filas con valores nulos
data_cleaned = data.dropna()

# Convertir columnas a tipos de datos adecuados si es necesario
# Por ejemplo, convertir una columna de fechas a tipo datetime
data_cleaned['fecha'] = pd.to_datetime(data_cleaned['fecha'])

# Filtrar datos según algún criterio
# Por ejemplo, seleccionar datos de un rango de fechas específico
data_filtered = data_cleaned[(data_cleaned['fecha'] >= '2020-01-01') & (data_cleaned['fecha'] <= '2020-12-31')]

# Mostrar las primeras filas del DataFrame procesado para verificar los cambios
data_filtered.head()
