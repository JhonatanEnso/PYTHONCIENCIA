# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/influencers.csv')
df
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         27 non-null     int64
#  1   full_text  27 non-null     object
#  2   favorites  26 non-null     float64
#  3   retweets   26 non-null     float64
#  4   mentions   26 non-null     float64
#  5   country    27 non-null     object
#  6   user       27 non-null     object
#  7   followers  26 non-null     float64
#  8   followees  27 non-null     int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 2.0+ KB

# %%
df_filtrado = df.dropna()
df_filtrado
# Out:
#         id                                          full_text  favorites  \
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# 12  183733                           Programming is the best!      467.0
# 13  183734                             I cannot believe this!       50.0
# 14  183735                             Buy this product NOW!!      418.0
# ...

# %% [markdown]
# limpiar un dataframe y poner una valor por defecto a todos los datos NaN

# %%
df_filtrado = df.fillna(0)
df_filtrado
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        0.0
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df[(df['favorites'] > 400) & (df['mentions'] >= 20)]
# Out:
#         id                                  full_text  favorites  retweets  \
# 23  183744                                Thanks man!      430.0     143.0
# 24  183745  There is nothing better than programming!      424.0     110.0
# 25  183746                                   BORED AF      488.0      28.0
#
#     mentions   country              user  followers  followees
# 23      28.0  ALICANTE  cristianoronaldo        NaN        351
# 24      29.0  ALICANTE  cristianoronaldo       82.0        351
# 25      27.0     ELCHE      danicarvajal       21.0       2721

# %%
def popularidad(fila):
    followers = fila['followers']
    followees = fila['followees']
    resultado = followees / followers
    return resultado

df['popularidad'] = df.apply(popularidad, axis=1)
df[df['popularidad'] >= 15]
# Out:
#         id               full_text  favorites  retweets  mentions country  \
# 14  183735  Buy this product NOW!!      418.0      24.0       2.0   ELCHE
# 17  183738  hmmm feeling bad today      296.0      93.0      29.0   ELCHE
# 25  183746                BORED AF      488.0      28.0      27.0   ELCHE
#
#             user  followers  followees  popularidad
# 14  danicarvajal       21.0       2721   129.571429
# 17  danicarvajal       21.0       2721   129.571429
# 25  danicarvajal       21.0       2721   129.571429

# %% [markdown]
# vamos agrupar por el campo COUNTRY y vamos a mostrar la media de dicho grupo

# %%
grupo = df.groupby(['country']).agg({
    "followers": "sum",
    "mentions": "mean",
    "retweets": "max",
})

grupo
# Out:
#           followers  mentions  retweets
# country
# ALICANTE     6166.0    19.600     145.0
# ELCHE         123.0    13.750     130.0
# MADRID       2884.0    11.875     146.0

# %%
grupo[grupo['followers'] > 5000]
# Out:
#           followers  mentions  retweets
# country
# ALICANTE     6166.0      19.6     145.0

# %% [markdown]
# vamos a almacenar en csv

# %%
grupo.to_csv('data/grupo.csv')

grupo.to_json('data/grupo.json')

# %%
grupo.to_excel('data/grupo.xlsx')
